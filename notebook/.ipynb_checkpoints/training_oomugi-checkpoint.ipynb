# %%
import numpy as np
from pathlib import Path

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.autograd import Variable
from torchvision.utils import save_image

# %%
import sys
import os
import time
# sys.path.append('../src/oomugi/')
sys.path.append(os.path.abspath('../src/oomugi/'))
import pprint
pprint.pprint(sys.path)

from model import UNet
from dataset import SSSDataset
from loss import DiscriminativeLoss
# Out:
# ['',
#  'C:\\Users\\y_kato\\Anaconda3\\envs\\pytorch0.3.1\\python36.zip',
#  'C:\\Users\\y_kato\\Anaconda3\\envs\\pytorch0.3.1\\DLLs',
#  'C:\\Users\\y_kato\\Anaconda3\\envs\\pytorch0.3.1\\lib',
#  'C:\\Users\\y_kato\\Anaconda3\\envs\\pytorch0.3.1',
#  'C:\\Users\\y_kato\\Anaconda3\\envs\\pytorch0.3.1\\lib\\site-packages',
#  'C:\\Users\\y_kato\\Anaconda3\\envs\\pytorch0.3.1\\lib\\site-packages\\win32',
#  'C:\\Users\\y_kato\\Anaconda3\\envs\\pytorch0.3.1\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\y_kato\\Anaconda3\\envs\\pytorch0.3.1\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\y_kato\\Anaconda3\\envs\\pytorch0.3.1\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\y_kato\\.ipython',
#  'I:\\ykato_git\\omg_instance_segmentation\\src\\pytorch-discriminative-loss-master\\src\\oomugi']

# %%
n_sticks = 8

# %%
# Model
model = UNet().cuda()

# %%
# Dataset for train
train_dataset = SSSDataset(train=True, n_sticks=n_sticks)
train_dataloader = DataLoader(train_dataset, batch_size=1,
                              shuffle=False, num_workers=0, pin_memory=True)

# %%
# Loss Function
criterion_disc = DiscriminativeLoss(delta_var=0.5,
                                    delta_dist=1.5,
                                    norm=2,
                                    usegpu=True).cuda()
criterion_ce = nn.CrossEntropyLoss().cuda()

# %%
# Optimizer
parameters = model.parameters()
optimizer = optim.SGD(parameters, lr=0.01, momentum=0.9, weight_decay=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer,
                                                 mode='min',
                                                 factor=0.1,
                                                 patience=10,
                                                 verbose=True)

# %%
# Train
model_dir = Path('../model')

best_loss = np.inf
start = time.time()
print("start")
for epoch in range(300):
    print(f'epoch : {epoch}')
    disc_losses = []
    ce_losses = []
    for batched in train_dataloader:
        images, sem_labels, ins_labels, ins_num = batched
        
        nb ,nc, nh, nw = sem_labels.size()
        
#         print('images ', images.numpy().shape)
#         print('sem_labels ', sem_labels.numpy().shape)
#         print('ins_labels ', ins_labels.numpy().shape)
#         save_image(images,'debug_images.png', padding=10)
# #         save_image(torch.from_numpy(sem_labels.numpy()[:,0,:,:]).contiguous(),'debug_sem_labels.png', padding=10)
# #         save_image(ins_labels,'debug_ins_labels.png', padding=10)
#         print(type(sem_labels), sem_labels.size())
#         tmpTensor = sem_labels[:,0,:,:].contiguous()
#         save_image(tmpTensor.view(nb, 1, nh, nw),'debug_sem_labels.png', padding=10)
#         for i in range(8):
#             tmpTensor = ins_labels[:,i,:,:].contiguous()
#             save_image(tmpTensor.view(nb, 1, nh, nw),'debug_ins_labels{}.png'.format(i), padding=10)
        
        
        images = Variable(images).cuda()
        sem_labels = Variable(sem_labels).cuda()
        ins_labels = Variable(ins_labels).cuda()
        model.zero_grad()

        sem_predict, ins_predict = model(images)
        loss = 0
        
#         print('sem_predict ', sem_predict.cpu().data.numpy().shape)
#         #save_image(sem_predict[:,0,:,:],'debug_sem_predict.png', padding=10)
#         tmpTensor = sem_predict.cpu().data
#         print(type(tmpTensor), tmpTensor.size())
#         tmpTensor = tmpTensor[:,0,:,:].contiguous()
#         save_image(tmpTensor.view(nb, 1, nh, nw),'debug_sem_predict.png', padding=10)
#         tmpTensor = ins_predict.cpu().data
#         print(type(tmpTensor), tmpTensor.size())
#         for i in range(16):
#             tmpTensor_a = tmpTensor[:,i,:,:].contiguous()
#             print('ins_predict', tmpTensor_a.view(nb, 1, nh, nw).size())
#             save_image(tmpTensor_a.view(nb, 1, nh, nw),'debug_ins_predict{}.png'.format(i), padding=10)

        # Discriminative Loss
#         disc_loss = criterion_disc(ins_predict,
#                                    ins_labels,
#                                    [n_sticks] * len(images))
#         print('ins_predict.size {}'.format(ins_predict.size()))
#         print('ins_labels.size {}'.format(ins_labels.size()))
#         print('ins_num.size {}'.format(ins_num.size()))
    
        disc_loss = criterion_disc(ins_predict,
                                   ins_labels,
                                   ins_num)
        loss += disc_loss
        disc_losses.append(disc_loss.cpu().data.numpy()[0])

        # Cross Entropy Loss
        _, sem_labels_ce = sem_labels.max(1)
        ce_loss = criterion_ce(sem_predict.permute(0, 2, 3, 1)\
                                   .contiguous().view(-1, 2),
                               sem_labels_ce.view(-1))
        loss += ce_loss
        ce_losses.append(ce_loss.cpu().data.numpy()[0])

        loss.backward()
        optimizer.step()
    disc_loss = np.mean(disc_losses)
    ce_loss = np.mean(ce_losses)
    print(f'DiscriminativeLoss: {disc_loss:.4f}')
    print(f'CrossEntropyLoss: {ce_loss:.4f}')
    scheduler.step(disc_loss)
    if disc_loss < best_loss:
        best_loss = disc_loss
        print('Best Model!')
        modelname = 'model.pth'
        torch.save(model.state_dict(), model_dir.joinpath(modelname))
        
elapsed_time = time.time() - start
print("elapsed_time:{0}".format(elapsed_time) + "[sec]")
# Out:
# start
# epoch : 0
# DiscriminativeLoss: 0.5819
# CrossEntropyLoss: 0.0255
# Best Model!
# epoch : 1
# DiscriminativeLoss: 0.5597
# CrossEntropyLoss: 0.0196
# Best Model!
# epoch : 2
# DiscriminativeLoss: 0.5460
# CrossEntropyLoss: 0.0190
# Best Model!
# epoch : 3
# DiscriminativeLoss: 0.5478
# CrossEntropyLoss: 0.0188
# epoch : 4
# DiscriminativeLoss: 0.5362
# CrossEntropyLoss: 0.0190
# Best Model!
# epoch : 5
# DiscriminativeLoss: 0.5342
# CrossEntropyLoss: 0.0184
# Best Model!
# epoch : 6
# DiscriminativeLoss: 0.5314
# CrossEntropyLoss: 0.0184
# Best Model!
# epoch : 7
# DiscriminativeLoss: 0.5408
# CrossEntropyLoss: 0.0187
# epoch : 8
# DiscriminativeLoss: 0.5206
# CrossEntropyLoss: 0.0180
# Best Model!
# epoch : 9
# DiscriminativeLoss: 0.5345
# CrossEntropyLoss: 0.0187
# epoch : 10
# DiscriminativeLoss: 0.5393
# CrossEntropyLoss: 0.0196
# epoch : 11
# DiscriminativeLoss: 0.5300
# CrossEntropyLoss: 0.0191
# epoch : 12
# DiscriminativeLoss: 0.5197
# CrossEntropyLoss: 0.0184
# Best Model!
# epoch : 13
# DiscriminativeLoss: 0.5200
# CrossEntropyLoss: 0.0188
# epoch : 14
# DiscriminativeLoss: 0.5165
# CrossEntropyLoss: 0.0192
# Best Model!
# epoch : 15
# DiscriminativeLoss: 0.5199
# CrossEntropyLoss: 0.0190
# epoch : 16
# DiscriminativeLoss: 0.5167
# CrossEntropyLoss: 0.0188
# epoch : 17
# DiscriminativeLoss: 0.5195
# CrossEntropyLoss: 0.0188
# epoch : 18
# DiscriminativeLoss: 0.5157
# CrossEntropyLoss: 0.0183
# Best Model!
# epoch : 19
# DiscriminativeLoss: 0.5318
# CrossEntropyLoss: 0.0187
# epoch : 20
# DiscriminativeLoss: 0.5394
# CrossEntropyLoss: 0.0196
# epoch : 21
# DiscriminativeLoss: 0.5250
# CrossEntropyLoss: 0.0196
# epoch : 22
# DiscriminativeLoss: 0.5162
# CrossEntropyLoss: 0.0189
# epoch : 23
# DiscriminativeLoss: 0.5147
# CrossEntropyLoss: 0.0187
# Best Model!
# epoch : 24
# DiscriminativeLoss: 0.5116
# CrossEntropyLoss: 0.0182
# Best Model!
# epoch : 25
# DiscriminativeLoss: 0.5141
# CrossEntropyLoss: 0.0181
# epoch : 26
# DiscriminativeLoss: 0.5068
# CrossEntropyLoss: 0.0182
# Best Model!
# epoch : 27
# DiscriminativeLoss: 0.5073
# CrossEntropyLoss: 0.0179
# epoch : 28
# DiscriminativeLoss: 0.5052
# CrossEntropyLoss: 0.0181
# Best Model!
# epoch : 29
# DiscriminativeLoss: 0.5066
# CrossEntropyLoss: 0.0180
# epoch : 30
# DiscriminativeLoss: 0.5071
# CrossEntropyLoss: 0.0182
# epoch : 31
# DiscriminativeLoss: 0.5102
# CrossEntropyLoss: 0.0183
# epoch : 32
# DiscriminativeLoss: 0.5146
# CrossEntropyLoss: 0.0182
# epoch : 33
# DiscriminativeLoss: 0.5215
# CrossEntropyLoss: 0.0190
# epoch : 34
# DiscriminativeLoss: 0.5189
# CrossEntropyLoss: 0.0188
# epoch : 35
# DiscriminativeLoss: 0.5224
# CrossEntropyLoss: 0.0182
# epoch : 36
# DiscriminativeLoss: 0.5275
# CrossEntropyLoss: 0.0187
# epoch : 37
# DiscriminativeLoss: 0.5242
# CrossEntropyLoss: 0.0188
# epoch : 38
# DiscriminativeLoss: 0.5179
# CrossEntropyLoss: 0.0183
# epoch : 39
# DiscriminativeLoss: 0.5181
# CrossEntropyLoss: 0.0186
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# epoch : 40
# DiscriminativeLoss: 0.5345
# CrossEntropyLoss: 0.0212
# epoch : 41
# DiscriminativeLoss: 0.5180
# CrossEntropyLoss: 0.0204
# epoch : 42
# DiscriminativeLoss: 0.5088
# CrossEntropyLoss: 0.0201
# epoch : 43
# DiscriminativeLoss: 0.4994
# CrossEntropyLoss: 0.0198
# Best Model!
# epoch : 44
# DiscriminativeLoss: 0.4922
# CrossEntropyLoss: 0.0196
# Best Model!
# epoch : 45
# DiscriminativeLoss: 0.4831
# CrossEntropyLoss: 0.0192
# Best Model!
# epoch : 46
# DiscriminativeLoss: 0.4758
# CrossEntropyLoss: 0.0189
# Best Model!
# epoch : 47
# DiscriminativeLoss: 0.4693
# CrossEntropyLoss: 0.0187
# Best Model!
# epoch : 48
# DiscriminativeLoss: 0.4629
# CrossEntropyLoss: 0.0185
# Best Model!
# epoch : 49
# DiscriminativeLoss: 0.4567
# CrossEntropyLoss: 0.0184
# Best Model!
# epoch : 50
# DiscriminativeLoss: 0.4518
# CrossEntropyLoss: 0.0183
# Best Model!
# epoch : 51
# DiscriminativeLoss: 0.4470
# CrossEntropyLoss: 0.0181
# Best Model!
# epoch : 52
# DiscriminativeLoss: 0.4426
# CrossEntropyLoss: 0.0180
# Best Model!
# epoch : 53
# DiscriminativeLoss: 0.4374
# CrossEntropyLoss: 0.0180
# Best Model!
# epoch : 54
# DiscriminativeLoss: 0.4342
# CrossEntropyLoss: 0.0179
# Best Model!
# epoch : 55
# DiscriminativeLoss: 0.4309
# CrossEntropyLoss: 0.0177
# Best Model!
# epoch : 56
# DiscriminativeLoss: 0.4254
# CrossEntropyLoss: 0.0178
# Best Model!
# epoch : 57
# DiscriminativeLoss: 0.4224
# CrossEntropyLoss: 0.0177
# Best Model!
# epoch : 58
# DiscriminativeLoss: 0.4175
# CrossEntropyLoss: 0.0175
# Best Model!
# epoch : 59
# DiscriminativeLoss: 0.4170
# CrossEntropyLoss: 0.0174
# Best Model!
# epoch : 60
# DiscriminativeLoss: 0.4093
# CrossEntropyLoss: 0.0174
# Best Model!
# epoch : 61
# DiscriminativeLoss: 0.4064
# CrossEntropyLoss: 0.0172
# Best Model!
# epoch : 62
# DiscriminativeLoss: 0.4054
# CrossEntropyLoss: 0.0172
# Best Model!
# epoch : 63
# DiscriminativeLoss: 0.4001
# CrossEntropyLoss: 0.0171
# Best Model!
# epoch : 64
# DiscriminativeLoss: 0.3975
# CrossEntropyLoss: 0.0169
# Best Model!
# epoch : 65
# DiscriminativeLoss: 0.3938
# CrossEntropyLoss: 0.0169
# Best Model!
# epoch : 66
# DiscriminativeLoss: 0.3910
# CrossEntropyLoss: 0.0169
# Best Model!
# epoch : 67
# DiscriminativeLoss: 0.3911
# CrossEntropyLoss: 0.0168
# epoch : 68
# DiscriminativeLoss: 0.3884
# CrossEntropyLoss: 0.0167
# Best Model!
# epoch : 69
# DiscriminativeLoss: 0.3824
# CrossEntropyLoss: 0.0167
# Best Model!
# epoch : 70
# DiscriminativeLoss: 0.3794
# CrossEntropyLoss: 0.0166
# Best Model!
# epoch : 71
# DiscriminativeLoss: 0.3753
# CrossEntropyLoss: 0.0165
# Best Model!
# epoch : 72
# DiscriminativeLoss: 0.3748
# CrossEntropyLoss: 0.0163
# Best Model!
# epoch : 73
# DiscriminativeLoss: 0.3719
# CrossEntropyLoss: 0.0164
# Best Model!
# epoch : 74
# DiscriminativeLoss: 0.3679
# CrossEntropyLoss: 0.0162
# Best Model!
# epoch : 75
# DiscriminativeLoss: 0.3646
# CrossEntropyLoss: 0.0162
# Best Model!
# epoch : 76
# DiscriminativeLoss: 0.3599
# CrossEntropyLoss: 0.0161
# Best Model!
# epoch : 77
# DiscriminativeLoss: 0.3579
# CrossEntropyLoss: 0.0160
# Best Model!
# epoch : 78
# DiscriminativeLoss: 0.3558
# CrossEntropyLoss: 0.0160
# Best Model!
# epoch : 79
# DiscriminativeLoss: 0.3541
# CrossEntropyLoss: 0.0159
# Best Model!
# epoch : 80
# DiscriminativeLoss: 0.3544
# CrossEntropyLoss: 0.0160
# epoch : 81
# DiscriminativeLoss: 0.3487
# CrossEntropyLoss: 0.0159
# Best Model!
# epoch : 82
# DiscriminativeLoss: 0.3454
# CrossEntropyLoss: 0.0159
# Best Model!
# epoch : 83
# DiscriminativeLoss: 0.3435
# CrossEntropyLoss: 0.0158
# Best Model!
# epoch : 84
# DiscriminativeLoss: 0.3415
# CrossEntropyLoss: 0.0158
# Best Model!
# epoch : 85
# DiscriminativeLoss: 0.3403
# CrossEntropyLoss: 0.0158
# Best Model!
# epoch : 86
# DiscriminativeLoss: 0.3380
# CrossEntropyLoss: 0.0157
# Best Model!
# epoch : 87
# DiscriminativeLoss: 0.3341
# CrossEntropyLoss: 0.0157
# Best Model!
# epoch : 88
# DiscriminativeLoss: 0.3327
# CrossEntropyLoss: 0.0156
# Best Model!
# epoch : 89
# DiscriminativeLoss: 0.3304
# CrossEntropyLoss: 0.0155
# Best Model!
# epoch : 90
# DiscriminativeLoss: 0.3302
# CrossEntropyLoss: 0.0155
# Best Model!
# epoch : 91
# DiscriminativeLoss: 0.3283
# CrossEntropyLoss: 0.0154
# Best Model!
# epoch : 92
# DiscriminativeLoss: 0.3243
# CrossEntropyLoss: 0.0153
# Best Model!
# epoch : 93
# DiscriminativeLoss: 0.3219
# CrossEntropyLoss: 0.0153
# Best Model!
# epoch : 94
# DiscriminativeLoss: 0.3224
# CrossEntropyLoss: 0.0153
# epoch : 95
# DiscriminativeLoss: 0.3202
# CrossEntropyLoss: 0.0152
# Best Model!
# epoch : 96
# DiscriminativeLoss: 0.3209
# CrossEntropyLoss: 0.0152
# epoch : 97
# DiscriminativeLoss: 0.3167
# CrossEntropyLoss: 0.0151
# Best Model!
# epoch : 98
# DiscriminativeLoss: 0.3163
# CrossEntropyLoss: 0.0151
# Best Model!
# epoch : 99
# DiscriminativeLoss: 0.3147
# CrossEntropyLoss: 0.0151
# Best Model!
# epoch : 100
# DiscriminativeLoss: 0.3114
# CrossEntropyLoss: 0.0150
# Best Model!
# epoch : 101
# DiscriminativeLoss: 0.3088
# CrossEntropyLoss: 0.0150
# Best Model!
# epoch : 102
# DiscriminativeLoss: 0.3115
# CrossEntropyLoss: 0.0149
# epoch : 103
# DiscriminativeLoss: 0.3078
# CrossEntropyLoss: 0.0149
# Best Model!
# epoch : 104
# DiscriminativeLoss: 0.3048
# CrossEntropyLoss: 0.0148
# Best Model!
# epoch : 105
# DiscriminativeLoss: 0.3063
# CrossEntropyLoss: 0.0148
# epoch : 106
# DiscriminativeLoss: 0.3038
# CrossEntropyLoss: 0.0147
# Best Model!
# epoch : 107
# DiscriminativeLoss: 0.3026
# CrossEntropyLoss: 0.0147
# Best Model!
# epoch : 108
# DiscriminativeLoss: 0.3013
# CrossEntropyLoss: 0.0146
# Best Model!
# epoch : 109
# DiscriminativeLoss: 0.2994
# CrossEntropyLoss: 0.0146
# Best Model!
# epoch : 110
# DiscriminativeLoss: 0.2978
# CrossEntropyLoss: 0.0146
# Best Model!
# epoch : 111
# DiscriminativeLoss: 0.2994
# CrossEntropyLoss: 0.0145
# epoch : 112
# DiscriminativeLoss: 0.2967
# CrossEntropyLoss: 0.0145
# Best Model!
# epoch : 113
# DiscriminativeLoss: 0.2933
# CrossEntropyLoss: 0.0144
# Best Model!
# epoch : 114
# DiscriminativeLoss: 0.2928
# CrossEntropyLoss: 0.0143
# Best Model!
# epoch : 115
# DiscriminativeLoss: 0.2921
# CrossEntropyLoss: 0.0143
# Best Model!
# epoch : 116
# DiscriminativeLoss: 0.2922
# CrossEntropyLoss: 0.0143
# epoch : 117
# DiscriminativeLoss: 0.2931
# CrossEntropyLoss: 0.0144
# epoch : 118
# DiscriminativeLoss: 0.2894
# CrossEntropyLoss: 0.0142
# Best Model!
# epoch : 119
# DiscriminativeLoss: 0.2871
# CrossEntropyLoss: 0.0143
# Best Model!
# epoch : 120
# DiscriminativeLoss: 0.2890
# CrossEntropyLoss: 0.0142
# epoch : 121
# DiscriminativeLoss: 0.2865
# CrossEntropyLoss: 0.0141
# Best Model!
# epoch : 122
# DiscriminativeLoss: 0.2857
# CrossEntropyLoss: 0.0142
# Best Model!
# epoch : 123
# DiscriminativeLoss: 0.2839
# CrossEntropyLoss: 0.0141
# Best Model!
# epoch : 124
# DiscriminativeLoss: 0.2815
# CrossEntropyLoss: 0.0141
# Best Model!
# epoch : 125
# DiscriminativeLoss: 0.2812
# CrossEntropyLoss: 0.0141
# Best Model!
# epoch : 126
# DiscriminativeLoss: 0.2796
# CrossEntropyLoss: 0.0141
# Best Model!
# epoch : 127
# DiscriminativeLoss: 0.2800
# CrossEntropyLoss: 0.0140
# epoch : 128
# DiscriminativeLoss: 0.2811
# CrossEntropyLoss: 0.0141
# epoch : 129
# DiscriminativeLoss: 0.2778
# CrossEntropyLoss: 0.0140
# Best Model!
# epoch : 130
# DiscriminativeLoss: 0.2778
# CrossEntropyLoss: 0.0140
# Best Model!
# epoch : 131
# DiscriminativeLoss: 0.2787
# CrossEntropyLoss: 0.0140
# epoch : 132
# DiscriminativeLoss: 0.2751
# CrossEntropyLoss: 0.0139
# Best Model!
# epoch : 133
# DiscriminativeLoss: 0.2741
# CrossEntropyLoss: 0.0139
# Best Model!
# epoch : 134
# DiscriminativeLoss: 0.2738
# CrossEntropyLoss: 0.0139
# Best Model!
# epoch : 135
# DiscriminativeLoss: 0.2727
# CrossEntropyLoss: 0.0138
# Best Model!
# epoch : 136
# DiscriminativeLoss: 0.2711
# CrossEntropyLoss: 0.0138
# Best Model!
# epoch : 137
# DiscriminativeLoss: 0.2694
# CrossEntropyLoss: 0.0138
# Best Model!
# epoch : 138
# DiscriminativeLoss: 0.2682
# CrossEntropyLoss: 0.0138
# Best Model!
# epoch : 139
# DiscriminativeLoss: 0.2695
# CrossEntropyLoss: 0.0137
# epoch : 140
# DiscriminativeLoss: 0.2687
# CrossEntropyLoss: 0.0137
# epoch : 141
# DiscriminativeLoss: 0.2663
# CrossEntropyLoss: 0.0136
# Best Model!
# epoch : 142
# DiscriminativeLoss: 0.2650
# CrossEntropyLoss: 0.0136
# Best Model!
# epoch : 143
# DiscriminativeLoss: 0.2664
# CrossEntropyLoss: 0.0136
# epoch : 144
# DiscriminativeLoss: 0.2662
# CrossEntropyLoss: 0.0135
# epoch : 145
# DiscriminativeLoss: 0.2648
# CrossEntropyLoss: 0.0135
# Best Model!
# epoch : 146
# DiscriminativeLoss: 0.2645
# CrossEntropyLoss: 0.0135
# Best Model!
# epoch : 147
# DiscriminativeLoss: 0.2658
# CrossEntropyLoss: 0.0135
# epoch : 148
# DiscriminativeLoss: 0.2642
# CrossEntropyLoss: 0.0135
# Best Model!
# epoch : 149
# DiscriminativeLoss: 0.2634
# CrossEntropyLoss: 0.0134
# Best Model!
# epoch : 150
# DiscriminativeLoss: 0.2628
# CrossEntropyLoss: 0.0134
# Best Model!
# epoch : 151
# DiscriminativeLoss: 0.2632
# CrossEntropyLoss: 0.0133
# epoch : 152
# DiscriminativeLoss: 0.2617
# CrossEntropyLoss: 0.0134
# Best Model!
# epoch : 153
# DiscriminativeLoss: 0.2603
# CrossEntropyLoss: 0.0133
# Best Model!
# epoch : 154
# DiscriminativeLoss: 0.2620
# CrossEntropyLoss: 0.0133
# epoch : 155
# DiscriminativeLoss: 0.2612
# CrossEntropyLoss: 0.0133
# epoch : 156
# DiscriminativeLoss: 0.2562
# CrossEntropyLoss: 0.0133
# Best Model!
# epoch : 157
# DiscriminativeLoss: 0.2582
# CrossEntropyLoss: 0.0132
# epoch : 158
# DiscriminativeLoss: 0.2598
# CrossEntropyLoss: 0.0132
# epoch : 159
# DiscriminativeLoss: 0.2563
# CrossEntropyLoss: 0.0132
# epoch : 160
# DiscriminativeLoss: 0.2550
# CrossEntropyLoss: 0.0131
# Best Model!
# epoch : 161
# DiscriminativeLoss: 0.2563
# CrossEntropyLoss: 0.0131
# epoch : 162
# DiscriminativeLoss: 0.2562
# CrossEntropyLoss: 0.0131
# epoch : 163
# DiscriminativeLoss: 0.2550
# CrossEntropyLoss: 0.0130
# Best Model!
# epoch : 164
# DiscriminativeLoss: 0.2529
# CrossEntropyLoss: 0.0130
# Best Model!
# epoch : 165
# DiscriminativeLoss: 0.2547
# CrossEntropyLoss: 0.0130
# epoch : 166
# DiscriminativeLoss: 0.2535
# CrossEntropyLoss: 0.0130
# epoch : 167
# DiscriminativeLoss: 0.2528
# CrossEntropyLoss: 0.0129
# Best Model!
# epoch : 168
# DiscriminativeLoss: 0.2527
# CrossEntropyLoss: 0.0130
# Best Model!
# epoch : 169
# DiscriminativeLoss: 0.2515
# CrossEntropyLoss: 0.0129
# Best Model!
# epoch : 170
# DiscriminativeLoss: 0.2505
# CrossEntropyLoss: 0.0129
# Best Model!
# epoch : 171
# DiscriminativeLoss: 0.2513
# CrossEntropyLoss: 0.0128
# epoch : 172
# DiscriminativeLoss: 0.2499
# CrossEntropyLoss: 0.0128
# Best Model!
# epoch : 173
# DiscriminativeLoss: 0.2497
# CrossEntropyLoss: 0.0128
# Best Model!
# epoch : 174
# DiscriminativeLoss: 0.2496
# CrossEntropyLoss: 0.0128
# Best Model!
# epoch : 175
# DiscriminativeLoss: 0.2501
# CrossEntropyLoss: 0.0128
# epoch : 176
# DiscriminativeLoss: 0.2512
# CrossEntropyLoss: 0.0129
# epoch : 177
# DiscriminativeLoss: 0.2494
# CrossEntropyLoss: 0.0127
# Best Model!
# epoch : 178
# DiscriminativeLoss: 0.2470
# CrossEntropyLoss: 0.0127
# Best Model!
# epoch : 179
# DiscriminativeLoss: 0.2481
# CrossEntropyLoss: 0.0127
# epoch : 180
# DiscriminativeLoss: 0.2476
# CrossEntropyLoss: 0.0127
# epoch : 181
# DiscriminativeLoss: 0.2471
# CrossEntropyLoss: 0.0126
# epoch : 182
# DiscriminativeLoss: 0.2461
# CrossEntropyLoss: 0.0126
# Best Model!
# epoch : 183
# DiscriminativeLoss: 0.2461
# CrossEntropyLoss: 0.0127
# Best Model!
# epoch : 184
# DiscriminativeLoss: 0.2444
# CrossEntropyLoss: 0.0126
# Best Model!
# epoch : 185
# DiscriminativeLoss: 0.2451
# CrossEntropyLoss: 0.0126
# epoch : 186
# DiscriminativeLoss: 0.2429
# CrossEntropyLoss: 0.0125
# Best Model!
# epoch : 187
# DiscriminativeLoss: 0.2456
# CrossEntropyLoss: 0.0126
# epoch : 188
# DiscriminativeLoss: 0.2432
# CrossEntropyLoss: 0.0125
# epoch : 189
# DiscriminativeLoss: 0.2438
# CrossEntropyLoss: 0.0125
# epoch : 190
# DiscriminativeLoss: 0.2450
# CrossEntropyLoss: 0.0125
# epoch : 191
# DiscriminativeLoss: 0.2420
# CrossEntropyLoss: 0.0125
# Best Model!
# epoch : 192
# DiscriminativeLoss: 0.2429
# CrossEntropyLoss: 0.0125
# epoch : 193
# DiscriminativeLoss: 0.2422
# CrossEntropyLoss: 0.0124
# epoch : 194
# DiscriminativeLoss: 0.2412
# CrossEntropyLoss: 0.0124
# Best Model!
# epoch : 195
# DiscriminativeLoss: 0.2384
# CrossEntropyLoss: 0.0124
# Best Model!
# epoch : 196
# DiscriminativeLoss: 0.2396
# CrossEntropyLoss: 0.0124
# epoch : 197
# DiscriminativeLoss: 0.2388
# CrossEntropyLoss: 0.0123
# epoch : 198
# DiscriminativeLoss: 0.2410
# CrossEntropyLoss: 0.0124
# epoch : 199
# DiscriminativeLoss: 0.2405
# CrossEntropyLoss: 0.0123
# epoch : 200
# DiscriminativeLoss: 0.2389
# CrossEntropyLoss: 0.0123
# epoch : 201
# DiscriminativeLoss: 0.2402
# CrossEntropyLoss: 0.0123
# epoch : 202
# DiscriminativeLoss: 0.2412
# CrossEntropyLoss: 0.0123
# epoch : 203
# DiscriminativeLoss: 0.2401
# CrossEntropyLoss: 0.0123
# epoch : 204
# DiscriminativeLoss: 0.2390
# CrossEntropyLoss: 0.0123
# epoch : 205
# DiscriminativeLoss: 0.2411
# CrossEntropyLoss: 0.0123
# epoch : 206
# DiscriminativeLoss: 0.2378
# CrossEntropyLoss: 0.0123
# Best Model!
# epoch : 207
# DiscriminativeLoss: 0.2373
# CrossEntropyLoss: 0.0122
# Best Model!
# epoch : 208
# DiscriminativeLoss: 0.2380
# CrossEntropyLoss: 0.0122
# epoch : 209
# DiscriminativeLoss: 0.2377
# CrossEntropyLoss: 0.0122
# epoch : 210
# DiscriminativeLoss: 0.2361
# CrossEntropyLoss: 0.0122
# Best Model!
# epoch : 211
# DiscriminativeLoss: 0.2364
# CrossEntropyLoss: 0.0121
# epoch : 212
# DiscriminativeLoss: 0.2351
# CrossEntropyLoss: 0.0121
# Best Model!
# epoch : 213
# DiscriminativeLoss: 0.2349
# CrossEntropyLoss: 0.0121
# Best Model!
# epoch : 214
# DiscriminativeLoss: 0.2354
# CrossEntropyLoss: 0.0121
# epoch : 215
# DiscriminativeLoss: 0.2338
# CrossEntropyLoss: 0.0121
# Best Model!
# epoch : 216
# DiscriminativeLoss: 0.2333
# CrossEntropyLoss: 0.0120
# Best Model!
# epoch : 217
# DiscriminativeLoss: 0.2336
# CrossEntropyLoss: 0.0120
# epoch : 218
# DiscriminativeLoss: 0.2323
# CrossEntropyLoss: 0.0120
# Best Model!
# epoch : 219
# DiscriminativeLoss: 0.2338
# CrossEntropyLoss: 0.0119
# epoch : 220
# DiscriminativeLoss: 0.2322
# CrossEntropyLoss: 0.0119
# Best Model!
# epoch : 221
# DiscriminativeLoss: 0.2304
# CrossEntropyLoss: 0.0120
# Best Model!
# epoch : 222
# DiscriminativeLoss: 0.2323
# CrossEntropyLoss: 0.0120
# epoch : 223
# DiscriminativeLoss: 0.2316
# CrossEntropyLoss: 0.0120
# epoch : 224
# DiscriminativeLoss: 0.2331
# CrossEntropyLoss: 0.0120
# epoch : 225
# DiscriminativeLoss: 0.2326
# CrossEntropyLoss: 0.0120
# epoch : 226
# DiscriminativeLoss: 0.2320
# CrossEntropyLoss: 0.0119
# epoch : 227
# DiscriminativeLoss: 0.2310
# CrossEntropyLoss: 0.0119
# epoch : 228
# DiscriminativeLoss: 0.2306
# CrossEntropyLoss: 0.0119
# epoch : 229
# DiscriminativeLoss: 0.2311
# CrossEntropyLoss: 0.0119
# epoch : 230
# DiscriminativeLoss: 0.2297
# CrossEntropyLoss: 0.0119
# Best Model!
# epoch : 231
# DiscriminativeLoss: 0.2284
# CrossEntropyLoss: 0.0118
# Best Model!
# epoch : 232
# DiscriminativeLoss: 0.2307
# CrossEntropyLoss: 0.0118
# epoch : 233
# DiscriminativeLoss: 0.2283
# CrossEntropyLoss: 0.0118
# Best Model!
# epoch : 234
# DiscriminativeLoss: 0.2298
# CrossEntropyLoss: 0.0118
# epoch : 235
# DiscriminativeLoss: 0.2279
# CrossEntropyLoss: 0.0118
# Best Model!
# epoch : 236
# DiscriminativeLoss: 0.2317
# CrossEntropyLoss: 0.0118
# epoch : 237
# DiscriminativeLoss: 0.2314
# CrossEntropyLoss: 0.0119
# epoch : 238
# DiscriminativeLoss: 0.2282
# CrossEntropyLoss: 0.0117
# epoch : 239
# DiscriminativeLoss: 0.2288
# CrossEntropyLoss: 0.0118
# epoch : 240
# DiscriminativeLoss: 0.2287
# CrossEntropyLoss: 0.0118
# epoch : 241
# DiscriminativeLoss: 0.2293
# CrossEntropyLoss: 0.0117
# epoch : 242
# DiscriminativeLoss: 0.2276
# CrossEntropyLoss: 0.0118
# Best Model!
# epoch : 243
# DiscriminativeLoss: 0.2274
# CrossEntropyLoss: 0.0117
# Best Model!
# epoch : 244
# DiscriminativeLoss: 0.2285
# CrossEntropyLoss: 0.0118
# epoch : 245
# DiscriminativeLoss: 0.2278
# CrossEntropyLoss: 0.0117
# epoch : 246
# DiscriminativeLoss: 0.2254
# CrossEntropyLoss: 0.0117
# Best Model!
# epoch : 247
# DiscriminativeLoss: 0.2249
# CrossEntropyLoss: 0.0116
# Best Model!
# epoch : 248
# DiscriminativeLoss: 0.2254
# CrossEntropyLoss: 0.0117
# epoch : 249
# DiscriminativeLoss: 0.2280
# CrossEntropyLoss: 0.0117
# epoch : 250
# DiscriminativeLoss: 0.2262
# CrossEntropyLoss: 0.0117
# epoch : 251
# DiscriminativeLoss: 0.2259
# CrossEntropyLoss: 0.0117
# epoch : 252
# DiscriminativeLoss: 0.2266
# CrossEntropyLoss: 0.0117
# epoch : 253
# DiscriminativeLoss: 0.2273
# CrossEntropyLoss: 0.0117
# epoch : 254
# DiscriminativeLoss: 0.2253
# CrossEntropyLoss: 0.0116
# epoch : 255
# DiscriminativeLoss: 0.2255
# CrossEntropyLoss: 0.0116
# epoch : 256
# DiscriminativeLoss: 0.2264
# CrossEntropyLoss: 0.0116
# epoch : 257
# DiscriminativeLoss: 0.2261
# CrossEntropyLoss: 0.0116
# epoch : 258
# DiscriminativeLoss: 0.2242
# CrossEntropyLoss: 0.0116
# Best Model!
# epoch : 259
# DiscriminativeLoss: 0.2242
# CrossEntropyLoss: 0.0115
# Best Model!
# epoch : 260
# DiscriminativeLoss: 0.2221
# CrossEntropyLoss: 0.0115
# Best Model!
# epoch : 261
# DiscriminativeLoss: 0.2241
# CrossEntropyLoss: 0.0116
# epoch : 262
# DiscriminativeLoss: 0.2255
# CrossEntropyLoss: 0.0116
# epoch : 263
# DiscriminativeLoss: 0.2250
# CrossEntropyLoss: 0.0116
# epoch : 264
# DiscriminativeLoss: 0.2222
# CrossEntropyLoss: 0.0115
# epoch : 265
# DiscriminativeLoss: 0.2234
# CrossEntropyLoss: 0.0116
# epoch : 266
# DiscriminativeLoss: 0.2237
# CrossEntropyLoss: 0.0115
# epoch : 267
# DiscriminativeLoss: 0.2223
# CrossEntropyLoss: 0.0115
# epoch : 268
# DiscriminativeLoss: 0.2237
# CrossEntropyLoss: 0.0116
# epoch : 269
# DiscriminativeLoss: 0.2217
# CrossEntropyLoss: 0.0116
# Best Model!
# epoch : 270
# DiscriminativeLoss: 0.2228
# CrossEntropyLoss: 0.0115
# epoch : 271
# DiscriminativeLoss: 0.2234
# CrossEntropyLoss: 0.0115
# epoch : 272
# DiscriminativeLoss: 0.2227
# CrossEntropyLoss: 0.0115
# epoch : 273
# DiscriminativeLoss: 0.2215
# CrossEntropyLoss: 0.0115
# Best Model!
# epoch : 274
# DiscriminativeLoss: 0.2218
# CrossEntropyLoss: 0.0115
# epoch : 275
# DiscriminativeLoss: 0.2214
# CrossEntropyLoss: 0.0115
# Best Model!
# epoch : 276
# DiscriminativeLoss: 0.2237
# CrossEntropyLoss: 0.0115
# epoch : 277
# DiscriminativeLoss: 0.2211
# CrossEntropyLoss: 0.0115
# Best Model!
# epoch : 278
# DiscriminativeLoss: 0.2207
# CrossEntropyLoss: 0.0115
# Best Model!
# epoch : 279
# DiscriminativeLoss: 0.2206
# CrossEntropyLoss: 0.0114
# Best Model!
# epoch : 280
# DiscriminativeLoss: 0.2208
# CrossEntropyLoss: 0.0114
# epoch : 281
# DiscriminativeLoss: 0.2193
# CrossEntropyLoss: 0.0114
# Best Model!
# epoch : 282
# DiscriminativeLoss: 0.2222
# CrossEntropyLoss: 0.0115
# epoch : 283
# DiscriminativeLoss: 0.2209
# CrossEntropyLoss: 0.0114
# epoch : 284
# DiscriminativeLoss: 0.2198
# CrossEntropyLoss: 0.0114
# epoch : 285
# DiscriminativeLoss: 0.2190
# CrossEntropyLoss: 0.0114
# Best Model!
# epoch : 286
# DiscriminativeLoss: 0.2194
# CrossEntropyLoss: 0.0113
# epoch : 287
# DiscriminativeLoss: 0.2189
# CrossEntropyLoss: 0.0113
# Best Model!
# epoch : 288
# DiscriminativeLoss: 0.2204
# CrossEntropyLoss: 0.0114
# epoch : 289
# DiscriminativeLoss: 0.2199
# CrossEntropyLoss: 0.0114
# epoch : 290
# DiscriminativeLoss: 0.2180
# CrossEntropyLoss: 0.0113
# Best Model!
# epoch : 291
# DiscriminativeLoss: 0.2203
# CrossEntropyLoss: 0.0114
# epoch : 292
# DiscriminativeLoss: 0.2172
# CrossEntropyLoss: 0.0113
# Best Model!
# epoch : 293
# DiscriminativeLoss: 0.2177
# CrossEntropyLoss: 0.0113
# epoch : 294
# DiscriminativeLoss: 0.2166
# CrossEntropyLoss: 0.0113
# Best Model!
# epoch : 295
# DiscriminativeLoss: 0.2156
# CrossEntropyLoss: 0.0113
# Best Model!
# epoch : 296
# DiscriminativeLoss: 0.2155
# CrossEntropyLoss: 0.0113
# Best Model!
# epoch : 297
# DiscriminativeLoss: 0.2168
# CrossEntropyLoss: 0.0113
# epoch : 298
# DiscriminativeLoss: 0.2181
# CrossEntropyLoss: 0.0113
# epoch : 299
# DiscriminativeLoss: 0.2188
# CrossEntropyLoss: 0.0113
# elapsed_time:216285.0267777443[sec]
