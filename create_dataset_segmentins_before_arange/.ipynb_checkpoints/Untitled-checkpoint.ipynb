# %%
import re
import os
import sys
import csv

# %%
# csv読み込んでleafとstemに分ける

dname = '../../datasets/omg_instance_segmentation/dataset_ver4/img/leaf_age900'
fname = dname + '/color_age{}.csv'

def print_list(title, output):
    print(title)
    for i in range(len(output)):
        print(output[i])
        
def get_color_list(csv_fname, type):
    with open(csv_fname, 'r') as f:
        reader = csv.reader(f)
        age = 0
        type = None
        for row in reader:
            if row[0] == 'age':
                age = row[1]
                continue

            if row[0] == 'type':
                type = row[1]
                continue

            if type == 'leaf':
                color_leaf.append(row)
                continue

            if type == 'stem':
                color_stem.append(row)
                continue

    

color_leaf = []
color_stem = []
with open(fname, 'r') as f:
    reader = csv.reader(f)
    age = 0
    type = None
    for row in reader:
        print(row)
        if row[0] == 'age':
            age = row[1]
            continue
            
        if row[0] == 'type':
            type = row[1]
            continue
        
        if type == 'leaf':
            color_leaf.append(row)
            continue
            
        if type == 'stem':
            color_stem.append(row)
            continue
    
    
print_list('color_leaf', color_leaf)
print_list('color_stem', color_stem)
# print('color_leaf', color_leaf)
# print('color_stem', color_stem)
# Out:
# ['age', '900']
# ['type', 'leaf']
# ['0', '0.4000000059604645', '0.0', '0.0']
# ['1', '0.4000000059604645', '0.03600001335144043', '0.0']
# ['2', '0.4000000059604645', '0.07199998199939728', '0.0']
# ['3', '0.4000000059604645', '0.10799999535083771', '0.0']
# ['4', '0.4000000059604645', '0.14400000870227814', '0.0']
# ['5', '0.4000000059604645', '0.18000002205371857', '0.0']
# ['6', '0.4000000059604645', '0.21599999070167542', '0.0']
# ['7', '0.4000000059604645', '0.25200000405311584', '0.0']
# ['8', '0.4000000059604645', '0.2880000174045563', '0.0']
# ['9', '0.4000000059604645', '0.3240000307559967', '0.0']
# ['10', '0.4000000059604645', '0.36000004410743713', '0.0']
# ['11', '0.4000000059604645', '0.3959999978542328', '0.0']
# ['12', '0.36800000071525574', '0.4000000059604645', '0.0']
# ['13', '0.3320000171661377', '0.4000000059604645', '0.0']
# ['14', '0.29600000381469727', '0.4000000059604645', '0.0']
# ['15', '0.2600000500679016', '0.4000000059604645', '0.0']
# ['16', '0.2240000218153', '0.4000000059604645', '0.0']
# ['17', '0.18800000846385956', '0.4000000059604645', '0.0']
# ['18', '0.15199995040893555', '0.4000000059604645', '0.0']
# ['19', '0.1159999892115593', '0.4000000059604645', '0.0']
# ['20', '0.07999997586011887', '0.4000000059604645', '0.0']
# ['21', '0.04400000721216202', '0.4000000059604645', '0.0']
# ['22', '0.007999992929399014', '0.4000000059604645', '0.0']
# ['23', '0.0', '0.4000000059604645', '0.02799997292459011']
# ['24', '0.0', '0.4000000059604645', '0.06400003284215927']
